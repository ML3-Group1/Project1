# %%
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot
import pandas as pd
init_notebook_mode(connected = True)
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
state_df = pd.read_csv('usa_state.csv', index_col=0)
state_df
# Out:
#              long        lat  group  order   region subregion
# 1      -87.462006  30.389681      1      1  alabama       NaN
# 2      -87.484932  30.372492      1      2  alabama       NaN
# 3      -87.525032  30.372492      1      3  alabama       NaN
# 4      -87.530762  30.332386      1      4  alabama       NaN
# 5      -87.570869  30.326654      1      5  alabama       NaN
# ...           ...        ...    ...    ...      ...       ...
# 15595 -106.856628  41.012318     63  15595  wyoming       NaN
# 15596 -107.309265  41.018047     63  15596  wyoming       NaN
# 15597 -107.922333  41.018047     63  15597  wyoming       NaN
# 15598 -109.056786  40.989399     63  15598  wyoming       NaN
# 15599 -109.051064  40.995129     63  15599  wyoming       NaN
#
# [15537 rows x 6 columns]

# %%
arrest_df = pd.read_csv('usa_arrests.csv', index_col=0)
arrest_df.shape
# Out:
# (50, 5)

# %%
merged_df = pd.merge(state_df, arrest_df, left_on='region', right_on='state', how='left')
ordered_df = merged_df.sort_values('order').reset_index(drop=True)
ordered_df.head()
# Out:
#         long        lat  group  order   region subregion    Murder   Assault  \
# 0 -87.462006  30.389681      1      1  alabama       NaN  1.242564  0.782839
# 1 -87.484932  30.372492      1      2  alabama       NaN  1.242564  0.782839
# 2 -87.525032  30.372492      1      3  alabama       NaN  1.242564  0.782839
# 3 -87.530762  30.332386      1      4  alabama       NaN  1.242564  0.782839
# 4 -87.570869  30.326654      1      5  alabama       NaN  1.242564  0.782839
#
#    UrbanPop      Rape    state
# 0 -0.520907 -0.003416  alabama
# 1 -0.520907 -0.003416  alabama
# 2 -0.520907 -0.003416  alabama
# 3 -0.520907 -0.003416  alabama
# 4 -0.520907 -0.003416  alabama

# %%
sdata_df = ordered_df[['long' , 'lat' , 'group' , 'region' , 'Murder' , 'Assault' , 'UrbanPop' , 'Rape']]

# %%
molten_data = pd.melt(sdata_df, id_vars=['long' , 'lat' , 'group' , 'region'])
molten_data
# Out:
#              long        lat  group   region variable     value
# 0      -87.462006  30.389681      1  alabama   Murder  1.242564
# 1      -87.484932  30.372492      1  alabama   Murder  1.242564
# 2      -87.525032  30.372492      1  alabama   Murder  1.242564
# 3      -87.530762  30.332386      1  alabama   Murder  1.242564
# 4      -87.570869  30.326654      1  alabama   Murder  1.242564
# ...           ...        ...    ...      ...      ...       ...
# 62143 -106.856628  41.012318     63  wyoming     Rape -0.601299
# 62144 -107.309265  41.018047     63  wyoming     Rape -0.601299
# 62145 -107.922333  41.018047     63  wyoming     Rape -0.601299
# 62146 -109.056786  40.989399     63  wyoming     Rape -0.601299
# 62147 -109.051064  40.995129     63  wyoming     Rape -0.601299
#
# [62148 rows x 6 columns]

# %%
data = dict(
        type = 'choropleth',
        colorscale = 'Viridis',
        locations = ordered_df['state'],
        locationmode = "USA-states",
        z = ordered_df['Murder'],
        text = ordered_df['state'],
        colorbar = {'title' : 'rate of crime in usa'},
      )

# %%
layout = dict(geo ={'scope': 'usa'})

# %%
choromap = go.Figure(data = [data], layout = layout)
iplot(choromap,validate=False)
# Out:
# <div>                            <div id="dd268b9d-9292-4a11-ba1e-baeb8ad0a1ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd268b9d-9292-4a11-ba1e-baeb8ad0a1ca")) {                    Plotly.newPlot(                        "dd268b9d-9292-4a11-ba1e-baeb8ad0a1ca",                        [{"colorbar":{"title":{"text":"rate of crime in usa"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"locationmode":"USA-states","locations":["alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","alabama","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona","arizona" ...

# %%
fig = px.choropleth(ordered_df, geojson=geo-usa, locations='states', color='Murder',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           scope="usa",
                           labels={'unemp':'unemployment rate'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-781f82a5d88a> in <module>
# ----> 1 fig = px.choropleth(ordered_df, geojson=geo-usa, locations='states', color='Murder',
#       2                            color_continuous_scale="Viridis",
#       3                            range_color=(0, 12),
#       4                            scope="usa",
#       5                            labels={'unemp':'unemployment rate'}
#
# NameError: name 'geo' is not defined
