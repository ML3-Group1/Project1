# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('Food_Establishment_Inspection_Data.csv')
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
# /var/folders/t4/bptgh3hx6bz480z9tyq5f9780000gn/T/ipykernel_75733/373263499.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Food_Establishment_Inspection_Data.csv')
#                Name Program_Identifier Inspection_Date  \
# 0  #807 TUTTA BELLA   #807 TUTTA BELLA      08/31/2022
# 1  #807 TUTTA BELLA   #807 TUTTA BELLA      08/31/2022
# 2  #807 TUTTA BELLA   #807 TUTTA BELLA      01/13/2022
# 3  #807 TUTTA BELLA   #807 TUTTA BELLA      01/06/2021
# 4         +MAS CAFE          +MAS CAFE      07/13/2022
#
#                         Description          Address     City Zip_Code  \
# 0  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 1  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 2  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 3  Seating 0-12 - Risk Category III  2746 NE 45TH ST  SEATTLE    98105
# 4  Seating 0-12 - Risk Category III  1906 N 34TH ST   SEATTLE    98103
#
#             Phone   Longitude   Latitude  ... Inspection_Score  \
# 0  (206) 722-6400 -122.296415  47.662311  ...             10.0
# 1  (206) 722-6400 -122.296415  47.662311  ...             10.0
# 2  (206) 722-6400 -122.296415  47.662311  ...              0.0
# 3  (206) 722-6400 -122.296415  47.662311  ...              0.0
# 4  (206) 491-4694 -122.334587  47.648180  ...              0.0
#
#   Inspection_Result  Inspection_Closed_Business Violation_Type  \
# 0    Unsatisfactory                       False           BLUE
# 1    Unsatisfactory                       False            RED
# 2      Satisfactory                       False            NaN
# 3      Satisfactory                       False            NaN
# 4      Satisfactory                       False            NaN
#
#                                Violation_Description Violation_Points  \
# 0  3200 - Insects, rodents, animals not present; ...                5
# 1  0200 - Food Worker Cards current for all food ...                5
# 2                                                NaN                0
# 3                                                NaN                0
# 4                                                NaN                0
#
#   Business_ID  Inspection_Serial_Num Violation_Record_ID Grade
# 0   PR0089260              DAEEWQC0L           IVQ7QYW2V   1.0
# 1   PR0089260              DAEEWQC0L           IV0J437H6   1.0
# 2   PR0089260              DAWWGK08K                 NaN   1.0
# 3   PR0089260              DAUHM2FT8                 NaN   1.0
# 4   PR0046367              DATSWIPUS                 NaN   2.0
#
# [5 rows x 22 columns]

# %%
df.isna().sum()
# Out:
# Name                               0
# Program_Identifier                 0
# Inspection_Date                  774
# Description                        0
# Address                            0
# City                               0
# Zip_Code                           0
# Phone                          71193
# Longitude                        330
# Latitude                         330
# Inspection_Business_Name         774
# Inspection_Type                  774
# Inspection_Score                 815
# Inspection_Result                774
# Inspection_Closed_Business       774
# Violation_Type                111478
# Violation_Description         111478
# Violation_Points                   0
# Business_ID                        0
# Inspection_Serial_Num            774
# Violation_Record_ID           111478
# Grade                          59513
# dtype: int64

# %%
#Dropping unusable columns and save to df2
df=df.drop(['Program_Identifier','Address','Phone','Business_ID','Violation_Record_ID','Zip_Code','Inspection_Business_Name','Inspection_Serial_Num'],axis='columns')

# %%
def City_longitude(city):
    location = geolocator.geocode(city)
    return location.longitude
def City_latitude(city):
    location = geolocator.geocode(city)
    return location.latitude

# %%
df["Longitude"].fillna(City_longitude(df["City"].values),inplace=True)
df["Latitude"].fillna(City_latitude(df["City"].values),inplace=True)

# %%
df.isna().sum()
# Out:
# Name                               0
# Inspection_Date                  774
# Description                        0
# City                               0
# Longitude                          0
# Latitude                           0
# Inspection_Type                  774
# Inspection_Score                 815
# Inspection_Result                774
# Inspection_Closed_Business       774
# Violation_Type                111478
# Violation_Description         111478
# Violation_Points                   0
# Grade                          59513
# dtype: int64

# %%
df = df.dropna( how='all',subset= ['Inspection_Date'])

# %%
df_mean=np.round(df.groupby(['Inspection_Result']).agg({'Inspection_Score':'mean'}))
feature_data = df_mean.index
feature_count=df_mean['Inspection_Score']
plt.figure(figsize = (20,3))
plt.bar(feature_data,feature_count)
plt.xticks(feature_count.index, feature_count.index.values,rotation=45)
plt.ylabel("Frequency")
plt.title('Inspection Score')
plt.show()

# %%
df.loc[:,('Inspection_Score')] =np.round( df.groupby(['Inspection_Result'], group_keys=False)['Inspection_Score']
                     .apply(lambda x: x.fillna(x.mean())))

# %%
df.loc[:,('Violation_Type')] =df['Violation_Type'].fillna("Green")

# %%
df['Violation_Description'] = df['Violation_Description'].fillna("No_violation")

# %%
df.loc[:,('Grade')] =np.round( df.groupby(['Inspection_Score'], group_keys=False)['Grade']
                     .apply(lambda x: x.fillna(x.mean())))

# %%
df.isna().sum()
# Out:
# Name                          0
# Inspection_Date               0
# Description                   0
# City                          0
# Longitude                     0
# Latitude                      0
# Inspection_Type               0
# Inspection_Score              0
# Inspection_Result             0
# Inspection_Closed_Business    0
# Violation_Type                0
# Violation_Description         0
# Violation_Points              0
# Grade                         0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=45)
sns.boxplot(data=df)
# Out:
# <AxesSubplot: >

# %%
df.describe()
# Out:
#            Longitude       Latitude  Inspection_Score  Violation_Points  \
# count  249804.000000  249804.000000     249804.000000     249804.000000
# mean     -122.256275      47.563756         14.147752          4.424861
# std         0.113753       0.128777         20.287694          6.165551
# min      -122.518749      47.155934        -30.000000          0.000000
# 25%      -122.333593      47.478803          0.000000          0.000000
# 50%      -122.299547      47.604297          5.000000          3.000000
# 75%      -122.197881      47.661558         20.000000          5.000000
# max      -121.090900      48.415296        178.000000         30.000000
#
#                Grade
# count  249804.000000
# mean        1.311688
# std         0.539006
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000

# %%
data=df.to_csv('Clean_Data.csv')
